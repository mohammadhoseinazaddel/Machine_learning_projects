# %% [markdown]
# روی دیتای
#
# cardio_train1
#
# شبکه عمیق خود را به صورت های
#
# sequentional functional classbase
#
# و تیون کردن هایپر پارمتر ها ترین کنید
#
# 1- حتما تنسور بورد داشته باشد و به صورت یک لینک داده شود
#
# 2-EarlyStopping
#
# 3-  در ابتدای هر ایپاک شماره ایپاک و مقدار لاس را در متن زیر پرینت کند
# in ... epoch loss is ...

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
data = pd.read_csv('cardio_train1.csv')
data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1     0.0
# 1     0       1     1.0
# 2     0       0     1.0
# 3     0       1     1.0
# 4     0       0     0.0

# %%
data.isna().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         1
# dtype: int64

# %%
X = data.iloc[:, 1:-1]
y = data.iloc[:, -1]

# %%
from sklearn.preprocessing import MinMaxScaler
mms = MinMaxScaler()
X = mms.fit_transform(X)

# %%
X
# Out:
# array([[0.58807588, 1.        , 0.57948718, ..., 0.        , 0.        ,
#         1.        ],
#        [0.73015873, 0.        , 0.51794872, ..., 0.        , 0.        ,
#         1.        ],
#        [0.6240031 , 0.        , 0.56410256, ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.64018583, 1.        , 0.65641026, ..., 0.        , 1.        ,
#         0.        ],
#        [0.90073558, 0.        , 0.55384615, ..., 0.        , 0.        ,
#         0.        ],
#        [0.75431669, 0.        , 0.58974359, ..., 0.        , 0.        ,
#         1.        ]])

# %%
np.shape(X)
# Out:
# (70000, 11)

# %%
y = pd.get_dummies(y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=33123)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(11, activation='relu', input_shape=(11,)),
    tf.keras.layers.Dense(30, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss=tf.keras.losses.CategoricalCrossentropy(), metrics=[tf.keras.metrics.CategoricalAccuracy()])

# %%
model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test), batch_size=800)
# Out:
# Epoch 1/10
# 66/66 [==============================] - 0s 2ms/step - loss: 0.6249 - categorical_accuracy: 0.6495 - val_loss: 0.6288 - val_categorical_accuracy: 0.6447
# Epoch 2/10
# 66/66 [==============================] - 0s 3ms/step - loss: 0.6249 - categorical_accuracy: 0.6490 - val_loss: 0.6293 - val_categorical_accuracy: 0.6435
# Epoch 3/10
# 66/66 [==============================] - 0s 3ms/step - loss: 0.6248 - categorical_accuracy: 0.6493 - val_loss: 0.6278 - val_categorical_accuracy: 0.6451
# Epoch 4/10
# 66/66 [==============================] - 0s 3ms/step - loss: 0.6244 - categorical_accuracy: 0.6510 - val_loss: 0.6276 - val_categorical_accuracy: 0.6438
# Epoch 5/10
# 66/66 [==============================] - 0s 3ms/step - loss: 0.6240 - categorical_accuracy: 0.6502 - val_loss: 0.6274 - val_categorical_accuracy: 0.6455
# Epoch 6/10
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
yr = data.iloc[:, -1]

# %%
np.unique(yr, return_counts=True)
# Out:
# (array([0, 1]), array([35021, 34979]))

# %%
rfc = RandomForestClassifier(n_estimators=200)
Xr_train, Xr_test, yr_train, yr_test = train_test_split(X, yr, random_state=33123)

# %%
rfc.fit(Xr_train, yr_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
from sklearn.metrics import classification_report

# %%
y_pred = rfc.predict(Xr_test)
print(classification_report(y_true=yr_test, y_pred=y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.72      0.71      8652
#            1       0.72      0.70      0.71      8848
#
#     accuracy                           0.71     17500
#    macro avg       0.71      0.71      0.71     17500
# weighted avg       0.71      0.71      0.71     17500

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(11, activation='relu', input_shape=(11,)),
    tf.keras.layers.Dense(30, activation='relu'),
    tf.keras.layers.Dense(60, activation='relu'),
    tf.keras.layers.Dense(25, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')
])
model.compile(optimizer=tf.keras.optimizers.Adam(0.001), loss=tf.keras.losses.CategoricalCrossentropy(), metrics=[tf.keras.metrics.CategoricalAccuracy()])

# %%
model.fit(X_train, y_train, epochs=500, validation_data=(X_test, y_test), batch_size=300)
# Out:
# Epoch 1/500
# 175/175 [==============================] - 1s 3ms/step - loss: 0.6624 - categorical_accuracy: 0.5999 - val_loss: 0.6517 - val_categorical_accuracy: 0.6122
# Epoch 2/500
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6400 - categorical_accuracy: 0.6293 - val_loss: 0.6441 - val_categorical_accuracy: 0.6265
# Epoch 3/500
# 175/175 [==============================] - 0s 2ms/step - loss: 0.6352 - categorical_accuracy: 0.6348 - val_loss: 0.6377 - val_categorical_accuracy: 0.6323
# Epoch 4/500
# 175/175 [==============================] - 0s 2ms/step - loss: 0.6333 - categorical_accuracy: 0.6384 - val_loss: 0.6351 - val_categorical_accuracy: 0.6371
# Epoch 5/500
# 175/175 [==============================] - 1s 3ms/step - loss: 0.6310 - categorical_accuracy: 0.6415 - val_loss: 0.6375 - val_categorical_accuracy: 0.6341
# Epoch 6/500
# ...

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_8 (Dense)              (None, 11)                132
# _________________________________________________________________
# dense_9 (Dense)              (None, 30)                360
# _________________________________________________________________
# dense_10 (Dense)             (None, 60)                1860
# _________________________________________________________________
# dense_11 (Dense)             (None, 25)                1525
# _________________________________________________________________
# dense_12 (Dense)             (None, 2)                 52
# ...
# Total params: 3,929
# Trainable params: 3,929
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.predict(X_test)[3]
# Out:
# array([0.48003444, 0.5199655 ], dtype=float32)

# %%
    now = datetime.datetime.now()
    timeLabel = (str(now.year) + "_" + str(now.month)+ "_"+ str(now.day)+ "_"+ str(now.hour) + "_" + str(now.minute) + "_" + str(now.second + 1) + "_mixed18seqs2Ys")
    tbCallBack = tf.keras.callbacks.TensorBoard(log_dir='./data/VVCDataset/Graph//'+timeLabel , histogram_freq=1, write_graph=True,
                                                write_images=True)
    callbacks=[tensorboard_callback ])

# %% [markdown]
# اگر در فایل باشه

# %%
    tracking_address = "/home/mhazad/Documents/VCCR/data/VVCDataset/Graph/2022_10_2_10_31_57_mixed18seqs2Ys"
    tb = program.TensorBoard()
    tb.configure(argv=[None, '--logdir', tracking_address])
    url = tb.launch()

# %% [markdown]
# اگر در نوت باشه

# %%
# %tensorboard --logdir = "data/VVCDataset/Graph/2022_11_15_7_28_23_mixed18seqs2Ys"

# %%
class TensorBoardTool:
    def __init__(self, dir_path):
        self.dir_path = dir_path
    def run(self):
        # Remove http messages
        # log = logging.getLogger('werkzeug').setLevel(logging.ERROR)
        # Start tensorboard server
        tb = program.TensorBoard(default.get_plugins())
        tb.configure(argv=[None, '--logdir', self.dir_path])
        url = tb.launch()
        sys.stdout.write('TensorBoard at %s \n' % url)

# %%
class LossAndErrorPrintingCallback(keras.callbacks.Callback):
    def on_train_batch_end(self, batch, logs=None):
        print(
            "Up to batch {}, the average loss is {:7.2f}.".format(batch, logs["loss"])
        )

    def on_test_batch_end(self, batch, logs=None):
        print(
            "Up to batch {}, the average loss is {:7.2f}.".format(batch, logs["loss"])
        )

    def on_epoch_end(self, epoch, logs=None):
        print(
            "The average loss for epoch {} is {:7.2f} "
            "and mean absolute error is {:7.2f}.".format(
                epoch, logs["loss"], logs["mean_absolute_error"]
            )
        )

# %%
my_callbacks = [
    tf.keras.callbacks.EarlyStopping(patience=2),
    tf.keras.callbacks.ModelCheckpoint(filepath='model.{epoch:02d}-{val_loss:.2f}.h5'),
    tf.keras.callbacks.TensorBoard(log_dir='./logs'),
    tf.keras.callbacks.LossAndErrorPrintingCallback
]

# %% [markdown]
# linux
# 1- با چه دستوری مسیر پایتون را پیدا کنیم
# wrereis which
# 2- با چه دستوری از نوع فایل مطمین میشبم
# file
# 3-منظور از اعداد نشان داده شده بعد از زدت دستور زیر چیست
# ls /proc/
# 4- دستوری که دایرکتوری بسازد که درون آن یک دایرکتوری دیگر هم هست
# mkdir -p test/ptest
# 5- با چه دستوری فایل بالا را به صورت ریکرسیو پاک می کنید
# rm -rf
# 6- با چه کامتد هایی میتوان فایل را خواند
# cat -n tac less more
# head -n 20
# 7- برای تعقیب تعییرات یک فایل چه دستوری را پیشنهاد میدهید
# tail -f
# 8- معادل دستورپرینت در بش چیست
# echo
